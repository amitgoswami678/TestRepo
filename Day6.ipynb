# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = 2
b = "ag"
c = True
d = None
e =1.1
print(a, b, c, d, e)
# Out:
# 2 ag True None

# %%
print(type(a) ,type(b) ,type(c), type(d))
# Out:
#   Cell In[3], line 1
#     print(type(a) type(b) type(c) type(d))
#                   ^
# SyntaxError: invalid syntax

# %%
print(type(a), type(b), type(c), type(d))
# Out:
# <class 'int'> <class 'str'> <class 'bool'> <class 'NoneType'>

# %%
a = 2
b = "ag"
c = True
d = None
e =1.1
f =complex(1, 2)
print(a, b, c, d, e, f)
# Out:
# 2 ag True None 1.1 (1+2j)

# %%
print("This is a test.")

# %%
list1 = [1, 2, 3]
list2 = ["a", "b", "c"]
list3 = [1, "a", True, None]
print(list1)
print(list2)    
print(list3)
# Out:
# [1, 2, 3]
# ['a', 'b', 'c']
# [1, 'a', True, None]

# %%
z = complex(1, 2)
print(z)
# Out:
# (1+2j)
